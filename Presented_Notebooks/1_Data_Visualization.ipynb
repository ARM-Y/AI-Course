# %% [markdown]
# ## Import required libararies

# %%
import numpy as np # linear algebra
import pandas as pd # data manipulation and analysis

import matplotlib.pyplot as plt # data visualization
import seaborn as sns # data visualization

# %% [markdown]
# ignoring warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading the dataset from Kaggle
# The dataset will be loaded as pandas DataFrame.
#
# Note that if you are running your code elsewhere, you must change the directory address.

# %%
df = pd.read_csv('/kaggle/input/insurance/insurance.csv')

# %% [markdown]
# ## Dataset

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# There are 1338 rows(observations) and 7 columns (features) in this dataset.

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %% [markdown]
# The fist 10 rows can be obtained with the above cell.

# %% [markdown]
# ## Dataset Characteristics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# ## Preprocessing
# For the visualization purposes, we will conduct a minimal preprocessing on the data, including removing the rows with #NA values.

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (1337, 7)

# %% [markdown]
# The remaining rows are 1337. (previously 1338)

# %% [markdown]
# ## Visulization

# %% [markdown]
# ### 1- Histograms
#
# You can follow the instructions for creating new plots. Moreover, the below code will generate the exact plot in the page 14 of the 4th session.

# %%
# Our DataFrame is named df and the column we want to plot is 'bmi'
name_of_column = df['bmi']

# Setting the number of bins for the histogram. you can change it to whatever you want
num_bins = 10

# Create a new figure and axis object
plt.hist(name_of_column, bins=num_bins, edgecolor='black', color='#1f77b4')

# Set the label for the x-axis
plt.xlabel('Values of BMI')

# Set the label for the y-axis
plt.ylabel('Frequency')

# Set the title of the histogram
plt.title('Histogram of BMI')

# Display the histogram
plt.show()

# %%
# Our DataFrame is named df and the column we want to plot is 'charges'
name_of_column = df['charges']

# Setting the number of bins for the histogram. you can change it to whatever you want
num_bins = 15

# Create a new figure and axis object
plt.hist(name_of_column, bins=num_bins, edgecolor='black', color='#1f77b4')

# Set the label for the x-axis
plt.xlabel('Values of Charges')

# Set the label for the y-axis
plt.ylabel('Frequency')

# Set the title of the histogram
plt.title('Histogram of Charges')

# Display the histogram
plt.show()

# %%
# Our DataFrame is named df and the column we want to plot is 'charges'
name_of_column = df['charges']

# Setting the number of bins for the histogram. you can change it to whatever you want
num_bins = 5

# Create a new figure and axis object
plt.hist(name_of_column, bins=num_bins, edgecolor='black', color='#1f77b4')

# Set the label for the x-axis
plt.xlabel('Values of Charges')

# Set the label for the y-axis
plt.ylabel('Frequency')

# Set the title of the histogram
plt.title('Histogram of Charges')

# Display the histogram
plt.show()

# %% [markdown]
# As you can see, the last two plots are the exact plots in the page 16 of session 4.

# %% [markdown]
# ### 2-Box plots

# %%
# Our DataFrame is named df and the column we want to plot is 'charges'
name_of_column = df['charges']

# Create a box plot
plt.boxplot(name_of_column)

# Set the label for the y-axis
plt.ylabel('Values of Charges')

# Set the title of the box plot
plt.title('Box Plot for Charges')

# Display the box plot
plt.show()

# %% [markdown]
# The below code will generate the exact plot in the page 13 of the 4th session.

# %%
# Our DataFrame is named df and the column we want to plot is 'bmi'
name_of_column = df['bmi']

# Create a box plot
plt.boxplot(name_of_column)

# Set the label for the y-axis
plt.ylabel('Values of BMI')

# Set the title of the box plot
plt.title('Box Plot for BMI')

# Display the box plot
plt.show()

# %%
# Our DataFrame is named df and the column we want to plot is 'children'
name_of_column = df['children']

# Create a box plot
plt.boxplot(name_of_column)

# Set the label for the y-axis
plt.ylabel('Number of Children')

# Set the title of the box plot
plt.title('Box Plot for Number of Childre')

# Display the box plot
plt.show()

# %% [markdown]
# ### 3-Scatter plots

# %%
# Our DataFrame is named df and the columns we want to plot are 'charges' and 'bmi'
x_data = df['bmi']
y_data = df['charges']

# Create a scatter plot
plt.scatter(x_data, y_data)

# Set the label for the x-axis
plt.xlabel('Values of BMI')

# Set the label for the y-axis
plt.ylabel('Values of Charges')

# Set the title of the scatter plot
plt.title('Scatter Plot of Charges vs BMI')

# Display the scatter plot
plt.show()

# %%
# Our DataFrame is named df and the columns we want to plot are 'charges' and 'age'
x_data = df['age']
y_data = df['charges']

# Create a scatter plot
plt.scatter(x_data, y_data)

# Set the label for the x-axis
plt.xlabel('Age of the Person')

# Set the label for the y-axis
plt.ylabel('Values of Charges')

# Set the title of the scatter plot
plt.title('Scatter Plot of Charges vs Age')

# Display the scatter plot
plt.show()

# %% [markdown]
# This is the plot for page 16 of session 4.

# %% [markdown]
# ### 4-Bar Charts
# Session 4 / slide 19 bar plot can be seen:

# %%
# Our DataFrame is named df and the column we want to plot is 'children'
name_of_column = df['children']

# Getting unique categories in the column
categories = name_of_column.unique()

#Getting the count of each category
category_counts = name_of_column.value_counts()

# Set a custom palette. We can change the palettes and the colors of our plot will change
custom_palette = sns.color_palette('Set2')  # Example: using the 'Set2' palette from seaborn

# Create a bar plot
plt.bar(categories, category_counts, color=custom_palette)

# Set the label for the x-axis
plt.xlabel('Number of Children')

# Set the label for the y-axis
plt.ylabel('Counts')

# Set the title of the bar plot
plt.title('Bar Plot')

# Display the bar plot
plt.show()

# %% [markdown]
# Here are some common palette names available in the seaborn library that you can use for your plots:
#
# * "deep"
#
# * "muted"
#
# * "bright"
#
# * "pastel"
#
# * "dark"
#
# * "colorblind"
#
# * "Set1"
#
# * "Set2"
#
# * "Set3"
#
# * "tab10"
#
# * "tab20"
#
# * "tab20b"
#
# * "tab20c"

# %% [markdown]
# Slide 19 bar plot:

# %%
# Our DataFrame is named df and the column we want to plot is 'smoker'
name_of_column = df['smoker']

# Getting unique categories in the column
categories = name_of_column.unique()

#Getting the count of each category
category_counts = name_of_column.value_counts()

# Set a custom palette. We can change the palettes and the colors of our plot will change
custom_palette = sns.color_palette('pastel')  # Example: using the 'pastel' palette from seaborn

# Create a bar plot
plt.bar(categories, category_counts, color=custom_palette)

# Set the label for the x-axis
plt.xlabel('Smoker or Not')

# Set the label for the y-axis
plt.ylabel('Counts')

# Set the title of the bar plot
plt.title('Bar Plot')

# Display the bar plot
plt.show()

# %% [markdown]
# ### 5-Pie Charts

# %%
# Our DataFrame is named df and the column we want to plot is 'smoker'
name_of_column = df['smoker']

# Getting unique categories in the column
categories = name_of_column.unique()

#Getting the count of each category
category_counts = name_of_column.value_counts()

# Create a pie chart
plt.pie(category_counts, labels=categories)

# Create a pie chart with percentage labels
plt.pie(category_counts, labels=categories, autopct='%1.1f%%')

# Set the title of the pie chart
plt.title('Pie Chart of Smokers and non Smokers')

# Display the pie chart
plt.show()

# %%
# Our DataFrame is named df and the column we want to plot is 'sex'
name_of_column = df['sex']

# Getting unique categories in the column
categories = name_of_column.unique()

#Getting the count of each category
category_counts = name_of_column.value_counts()

# Create a pie chart
plt.pie(category_counts, labels=categories)

# Create a pie chart with percentage labels
plt.pie(category_counts, labels=categories, autopct='%1.1f%%')

# Set the title of the pie chart
plt.title('Pie Chart of Genders')

# Display the pie chart
plt.show()

# %% [markdown]
# ### 6-Pair Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Generate the pair plot
sns.pairplot(df)

# Display the plot
plt.show()

# %% [markdown]
# This is the pairplot shown in the 21st slide of session 4.
